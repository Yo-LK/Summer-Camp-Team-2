# %% [markdown]
# # CWRU Bearing Data Download & Exploration
#
# Downloads the normal baseline and 48k-drive-end fault `.mat` files from CWRU's bearing data center into `data/` (skipping any already present), then explores the resulting dataset.

# %% [markdown]
# ## 1. Download data

# %%
import os

import requests

DATA_DIR = "data"
NORMAL_DIR = os.path.join(DATA_DIR, "normal_baseline_data")
DRIVE_END_48K_DIR = os.path.join(DATA_DIR, "48k_drive_end_fault")
os.makedirs(NORMAL_DIR, exist_ok=True)
os.makedirs(DRIVE_END_48K_DIR, exist_ok=True)

# Normal baseline files: {load_hp: file_number}
normal_files = {0: 97, 1: 98, 2: 99, 3: 100}

# Approximate motor speed by load, per the CWRU bearing data center page.
LOAD_RPM = {0: 1797, 1: 1772, 2: 1750, 3: 1730}

# %%
def _entries(file_numbers, fault_location, fault_diameter_in, position=None):
    """Build {file_number: metadata} for one fault type/diameter across loads 0-3 hp."""
    entries = {}
    for file_number, load_hp in zip(file_numbers, sorted(LOAD_RPM)):
        meta = {
            "fault_location": fault_location,
            "fault_diameter_in": fault_diameter_in,
            "load_hp": load_hp,
            "rpm": LOAD_RPM[load_hp],
        }
        if position:
            meta["position"] = position
        entries[file_number] = meta
    return entries


# 48k drive-end bearing fault files: {file_number: metadata}.
# Source: https://engineering.case.edu/bearingdatacenter/48k-drive-end-bearing-fault-data
drive_end_48k_files = {
    **_entries([109, 110, 111, 112], "inner_race", 0.007),
    **_entries([122, 123, 124, 125], "ball", 0.007),
    **_entries([135, 136, 137, 138], "outer_race", 0.007, "6:00"),
    **_entries([148, 149, 150, 151], "outer_race", 0.007, "3:00"),
    **_entries([161, 162, 163, 164], "outer_race", 0.007, "12:00"),
    **_entries([174, 175, 176, 177], "inner_race", 0.014),
    **_entries([189, 190, 191, 192], "ball", 0.014),
    **_entries([201, 202, 203, 204], "outer_race", 0.014, "6:00"),
    **_entries([213, 214, 215, 217], "inner_race", 0.021),
    **_entries([226, 227, 228, 229], "ball", 0.021),
    **_entries([238, 239, 240, 241], "outer_race", 0.021, "6:00"),
    **_entries([250, 251, 252, 253], "outer_race", 0.021, "3:00"),
    **_entries([262, 263, 264, 265], "outer_race", 0.021, "12:00"),
}

# %%
base_url = "https://engineering.case.edu/sites/default/files/{}.mat"


def build_filename(file_number: int, meta: dict) -> str:
    """Turn a drive_end_48k_files entry into a descriptive filename."""
    parts = [
        "48k_drive_end_fault",
        meta["fault_location"],
        f"{meta['fault_diameter_in']:.3f}in",
        f"{meta['load_hp']}hp",
        f"{meta['rpm']}rpm",
    ]
    if "position" in meta:
        parts.append(meta["position"].replace(":", "-"))
    parts.append(str(file_number))
    return "_".join(parts) + ".mat"


def download_if_missing(file_number: int, filename: str, dest_dir: str) -> None:
    """Download a CWRU .mat file into dest_dir, unless it's already there."""
    destination = os.path.join(dest_dir, filename)
    if os.path.exists(destination):
        print(f"Skipping {filename}: already exists in {dest_dir}")
        return

    url = base_url.format(file_number)
    temp_destination = f"{destination}.part"

    for attempt in range(3):
        try:
            response = requests.get(url, timeout=30, stream=True)
            response.raise_for_status()

            with open(temp_destination, "wb") as f:
                for chunk in response.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)

            os.replace(temp_destination, destination)
            print(f"Downloaded {url} -> {destination}")
            return
        except requests.RequestException as exc:
            if os.path.exists(temp_destination):
                os.remove(temp_destination)
            if attempt == 2:
                raise
            print(f"Download failed for {filename} (attempt {attempt + 1}/3): {exc}. Retrying...")

# %%
for load, num in normal_files.items():
    filename = f"normal_{load}hp.mat"
    download_if_missing(num, filename, NORMAL_DIR)

for file_number, meta in drive_end_48k_files.items():
    filename = build_filename(file_number, meta)
    download_if_missing(file_number, filename, DRIVE_END_48K_DIR)
# Out:
# Skipping normal_0hp.mat: already exists in data/normal_baseline_data
# Skipping normal_1hp.mat: already exists in data/normal_baseline_data
# Skipping normal_2hp.mat: already exists in data/normal_baseline_data
# Skipping normal_3hp.mat: already exists in data/normal_baseline_data
# Skipping 48k_drive_end_fault_inner_race_0.007in_0hp_1797rpm_109.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.007in_1hp_1772rpm_110.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.007in_2hp_1750rpm_111.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.007in_3hp_1730rpm_112.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.007in_0hp_1797rpm_122.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.007in_1hp_1772rpm_123.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.007in_2hp_1750rpm_124.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.007in_3hp_1730rpm_125.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_0hp_1797rpm_6-00_135.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_1hp_1772rpm_6-00_136.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_2hp_1750rpm_6-00_137.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_3hp_1730rpm_6-00_138.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_0hp_1797rpm_3-00_148.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_1hp_1772rpm_3-00_149.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_2hp_1750rpm_3-00_150.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_3hp_1730rpm_3-00_151.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_0hp_1797rpm_12-00_161.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_1hp_1772rpm_12-00_162.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_2hp_1750rpm_12-00_163.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.007in_3hp_1730rpm_12-00_164.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.014in_0hp_1797rpm_174.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.014in_1hp_1772rpm_175.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.014in_2hp_1750rpm_176.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.014in_3hp_1730rpm_177.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.014in_0hp_1797rpm_189.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.014in_1hp_1772rpm_190.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.014in_2hp_1750rpm_191.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.014in_3hp_1730rpm_192.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.014in_0hp_1797rpm_6-00_201.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.014in_1hp_1772rpm_6-00_202.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.014in_2hp_1750rpm_6-00_203.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.014in_3hp_1730rpm_6-00_204.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.021in_0hp_1797rpm_213.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.021in_1hp_1772rpm_214.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.021in_2hp_1750rpm_215.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_inner_race_0.021in_3hp_1730rpm_217.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.021in_0hp_1797rpm_226.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.021in_1hp_1772rpm_227.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.021in_2hp_1750rpm_228.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_ball_0.021in_3hp_1730rpm_229.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_0hp_1797rpm_6-00_238.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_1hp_1772rpm_6-00_239.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_2hp_1750rpm_6-00_240.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_3hp_1730rpm_6-00_241.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_0hp_1797rpm_3-00_250.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_1hp_1772rpm_3-00_251.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_2hp_1750rpm_3-00_252.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_3hp_1730rpm_3-00_253.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_0hp_1797rpm_12-00_262.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_1hp_1772rpm_12-00_263.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_2hp_1750rpm_12-00_264.mat: already exists in data/48k_drive_end_fault
# Skipping 48k_drive_end_fault_outer_race_0.021in_3hp_1730rpm_12-00_265.mat: already exists in data/48k_drive_end_fault

# %% [markdown]
# ## 2. Explore data

# %%
import re

import numpy as np
import pandas as pd
from scipy.io import loadmat
import matplotlib.pyplot as plt

SAMPLE_RATE_HZ = 48_000  # all files here are from CWRU's 48k drive-end fault dataset

# Raw source files across both labeled subfolders, as paths relative to the project root
files = sorted(
    os.path.join(sub_dir, f)
    for sub_dir in (NORMAL_DIR, DRIVE_END_48K_DIR)
    for f in os.listdir(sub_dir)
)
print(f"{len(files)} files across {NORMAL_DIR}/ and {DRIVE_END_48K_DIR}/")
files[:5]
# Out:
# 56 files across data/normal_baseline_data/ and data/48k_drive_end_fault/
# ['data/48k_drive_end_fault/48k_drive_end_fault_ball_0.007in_0hp_1797rpm_122.mat',
#  'data/48k_drive_end_fault/48k_drive_end_fault_ball_0.007in_1hp_1772rpm_123.mat',
#  'data/48k_drive_end_fault/48k_drive_end_fault_ball_0.007in_2hp_1750rpm_124.mat',
#  'data/48k_drive_end_fault/48k_drive_end_fault_ball_0.007in_3hp_1730rpm_125.mat',
#  'data/48k_drive_end_fault/48k_drive_end_fault_ball_0.014in_0hp_1797rpm_189.mat']

# %% [markdown]
# ### Inspect a single sample
#
# Before building any general-purpose loading logic, look at one raw `.mat` file directly to see how CWRU structures the data (variable names, shapes, dtypes).

# %%
sample_path = files[0]
sample_mat = loadmat(sample_path)

print(f"File: {sample_path}")
for key, value in sample_mat.items():
    if key.startswith("__"):
        continue  # skip MATLAB's internal metadata keys (__header__, __version__, __globals__)
    print(f"{key}: shape={getattr(value, 'shape', None)}, dtype={getattr(value, 'dtype', None)}")

# Peek at the first few raw samples of the drive-end signal
de_key = [k for k in sample_mat if k.endswith("DE_time")][0]
sample_mat[de_key][:10]
# Out:
# File: data/48k_drive_end_fault/48k_drive_end_fault_ball_0.007in_0hp_1797rpm_122.mat
# X122_DE_time: shape=(244739, 1), dtype=float64
# X122_FE_time: shape=(244739, 1), dtype=float64
# X122RPM: shape=(1, 1), dtype=uint16
# array([[-0.111192  ],
#        [-0.08302892],
#        [-0.04234892],
#        [ 0.00897046],
#        [ 0.05757785],
#        [ 0.09512862],
#        [ 0.12099692],
#        [ 0.13267938],
#        [ 0.13789477],
#        [ 0.12913292]])

# %%
NORMAL_RECORD_IDS = {
    "normal_0hp.mat": 97,
    "normal_1hp.mat": 98,
    "normal_2hp.mat": 99,
    "normal_3hp.mat": 100,
}


def expected_record_id(path):
    """Return the original CWRU record number represented by path."""
    filename = os.path.basename(path)
    if filename in NORMAL_RECORD_IDS:
        return NORMAL_RECORD_IDS[filename]

    # Descriptive project filename ending in the original CWRU record number.
    match = re.search(r"_(\d+)\.mat$", filename)
    if match:
        return int(match.group(1))

    # Unrenamed CWRU filename, for example 99.mat.
    match = re.fullmatch(r"(\d+)\.mat", filename)
    if match:
        return int(match.group(1))

    raise ValueError(f"cannot determine CWRU record number from '{filename}'")


def load_signals(path):
    """Load the DE/FE/BA/RPM variables belonging to this CWRU record.

    Some CWRU files contain variables copied from another record, so a suffix-only
    key match (e.g. any key ending in "DE_time") can silently load the wrong signal
    when a file has more than one such key. When the filename encodes the original
    CWRU record number, that's used to pick the exact key and rule out ambiguity.
    Otherwise (e.g. a freshly uploaded file with an arbitrary filename), this falls
    back to a plain suffix match — fine as long as there's exactly one candidate key;
    it only raises if multiple candidates exist and there's no filename-derived record
    number available to disambiguate between them.
    """
    mat = loadmat(path)
    try:
        prefix = f"X{expected_record_id(path):03d}"
    except ValueError:
        prefix = None

    def find(suffix, required=False):
        if prefix is not None:
            expected_key = f"{prefix}RPM" if suffix == "RPM" else f"{prefix}_{suffix}"
            if expected_key in mat:
                return np.asarray(mat[expected_key]).flatten()

        candidates = sorted(
            key for key in mat
            if not key.startswith("__") and key.endswith(suffix)
        )
        if len(candidates) == 1:
            return np.asarray(mat[candidates[0]]).flatten()

        if candidates and required:
            raise ValueError(
                f"{os.path.basename(path)}: multiple keys end with '{suffix}' {candidates} "
                "and the record number could not be resolved from the filename to disambiguate them"
            )
        if required and not candidates:
            raise ValueError(f"{os.path.basename(path)}: no key ending with '{suffix}' found")
        return None

    de = find("DE_time", required=True)
    fe = find("FE_time")
    ba = find("BA_time")
    rpm_arr = find("RPM")
    rpm = int(rpm_arr[0]) if rpm_arr is not None else None
    return de, fe, ba, rpm


# Matches the descriptive filenames produced by build_filename() above,
# e.g. 48k_drive_end_fault_inner_race_0.007in_0hp_1797rpm_6-00_135.mat
FAULT_NAME_RE = re.compile(
    r"48k_drive_end_fault_"
    r"(?P<location>inner_race|ball|outer_race)_"
    r"(?P<diameter>[\d.]+)in_(?P<load>\d+)hp_(?P<rpm>\d+)rpm"
    r"(?:_(?P<position>\d+-\d+))?_(?P<file_number>\d+)\.mat"
)


def label_file(path):
    """Pull fault metadata straight out of the descriptive filename."""
    filename = os.path.basename(path)
    if filename.startswith("normal"):
        hp = int(re.search(r"(\d+)hp", filename).group(1))
        return {"category": "normal", "load_hp": hp}

    match = FAULT_NAME_RE.match(filename)
    return {
        "category": "fault",
        "fault_location": match["location"],
        "fault_diameter_in": float(match["diameter"]),
        "load_hp": int(match["load"]),
        "rpm": int(match["rpm"]),
        # position only applies to outer-race faults (6:00/3:00/12:00 relative to load zone)
        "position": match["position"].replace("-", ":") if match["position"] else None,
        "file_number": int(match["file_number"]),
    }


manifest_rows = []
for path in files:
    info = label_file(path)
    de, fe, ba, rpm_reported = load_signals(path)
    manifest_rows.append({
        "filename": os.path.basename(path),
        "path": path,
        **info,
        "de_len": len(de) if de is not None else None,
        "fe_len": len(fe) if fe is not None else None,
        "ba_len": len(ba) if ba is not None else None,
        "rpm_reported": rpm_reported,  # actual RPM logged in the .mat file, vs. nominal rpm from filename
        "duration_s": round(len(de) / SAMPLE_RATE_HZ, 2) if de is not None else None,
    })

manifest = pd.DataFrame(manifest_rows)
manifest
# Out:
#                                              filename  \
# 0   48k_drive_end_fault_ball_0.007in_0hp_1797rpm_1...
# 1   48k_drive_end_fault_ball_0.007in_1hp_1772rpm_1...
# 2   48k_drive_end_fault_ball_0.007in_2hp_1750rpm_1...
# 3   48k_drive_end_fault_ball_0.007in_3hp_1730rpm_1...
# 4   48k_drive_end_fault_ball_0.014in_0hp_1797rpm_1...
# 5   48k_drive_end_fault_ball_0.014in_1hp_1772rpm_1...
# 6   48k_drive_end_fault_ball_0.014in_2hp_1750rpm_1...
# 7   48k_drive_end_fault_ball_0.014in_3hp_1730rpm_1...
# 8   48k_drive_end_fault_ball_0.021in_0hp_1797rpm_2...
# 9   48k_drive_end_fault_ball_0.021in_1hp_1772rpm_2...
# 10  48k_drive_end_fault_ball_0.021in_2hp_1750rpm_2...
# 11  48k_drive_end_fault_ball_0.021in_3hp_1730rpm_2...
# 12  48k_drive_end_fault_inner_race_0.007in_0hp_179...
# 13  48k_drive_end_fault_inner_race_0.007in_1hp_177...
# 14  48k_drive_end_fault_inner_race_0.007in_2hp_175...
# 15  48k_drive_end_fault_inner_race_0.007in_3hp_173...
# 16  48k_drive_end_fault_inner_race_0.014in_0hp_179...
# 17  48k_drive_end_fault_inner_race_0.014in_1hp_177...
# 18  48k_drive_end_fault_inner_race_0.014in_2hp_175...
# 19  48k_drive_end_fault_inner_race_0.014in_3hp_173...
# 20  48k_drive_end_fault_inner_race_0.021in_0hp_179...
# 21  48k_drive_end_fault_inner_race_0.021in_1hp_177...
# 22  48k_drive_end_fault_inner_race_0.021in_2hp_175...
# 23  48k_drive_end_fault_inner_race_0.021in_3hp_173...
# 24  48k_drive_end_fault_outer_race_0.007in_0hp_179...
# 25  48k_drive_end_fault_outer_race_0.007in_0hp_179...
# 26  48k_drive_end_fault_outer_race_0.007in_0hp_179...
# 27  48k_drive_end_fault_outer_race_0.007in_1hp_177...
# 28  48k_drive_end_fault_outer_race_0.007in_1hp_177...
# 29  48k_drive_end_fault_outer_race_0.007in_1hp_177...
# 30  48k_drive_end_fault_outer_race_0.007in_2hp_175...
# 31  48k_drive_end_fault_outer_race_0.007in_2hp_175...
# 32  48k_drive_end_fault_outer_race_0.007in_2hp_175...
# 33  48k_drive_end_fault_outer_race_0.007in_3hp_173...
# 34  48k_drive_end_fault_outer_race_0.007in_3hp_173...
# 35  48k_drive_end_fault_outer_race_0.007in_3hp_173...
# 36  48k_drive_end_fault_outer_race_0.014in_0hp_179...
# 37  48k_drive_end_fault_outer_race_0.014in_1hp_177...
# 38  48k_drive_end_fault_outer_race_0.014in_2hp_175...
# 39  48k_drive_end_fault_outer_race_0.014in_3hp_173...
# 40  48k_drive_end_fault_outer_race_0.021in_0hp_179...
# 41  48k_drive_end_fault_outer_race_0.021in_0hp_179...
# 42  48k_drive_end_fault_outer_race_0.021in_0hp_179...
# 43  48k_drive_end_fault_outer_race_0.021in_1hp_177...
# 44  48k_drive_end_fault_outer_race_0.021in_1hp_177...
# 45  48k_drive_end_fault_outer_race_0.021in_1hp_177...
# 46  48k_drive_end_fault_outer_race_0.021in_2hp_175...
# 47  48k_drive_end_fault_outer_race_0.021in_2hp_175...
# 48  48k_drive_end_fault_outer_race_0.021in_2hp_175...
# 49  48k_drive_end_fault_outer_race_0.021in_3hp_173...
# 50  48k_drive_end_fault_outer_race_0.021in_3hp_173...
# 51  48k_drive_end_fault_outer_race_0.021in_3hp_173...
# 52                                     normal_0hp.mat
# 53                                     normal_1hp.mat
# 54                                     normal_2hp.mat
# 55                                     normal_3hp.mat
#
#                                                  path category fault_location  \
# 0   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 1   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 2   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 3   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 4   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 5   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 6   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 7   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 8   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 9   data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 10  data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 11  data/48k_drive_end_fault/48k_drive_end_fault_b...    fault           ball
# 12  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 13  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 14  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 15  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 16  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 17  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 18  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 19  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 20  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 21  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 22  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 23  data/48k_drive_end_fault/48k_drive_end_fault_i...    fault     inner_race
# 24  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 25  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 26  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 27  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 28  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 29  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 30  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 31  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 32  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 33  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 34  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 35  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 36  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 37  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 38  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 39  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 40  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 41  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 42  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 43  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 44  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 45  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 46  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 47  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 48  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 49  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 50  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 51  data/48k_drive_end_fault/48k_drive_end_fault_o...    fault     outer_race
# 52           data/normal_baseline_data/normal_0hp.mat   normal            NaN
# 53           data/normal_baseline_data/normal_1hp.mat   normal            NaN
# 54           data/normal_baseline_data/normal_2hp.mat   normal            NaN
# 55           data/normal_baseline_data/normal_3hp.mat   normal            NaN
#
#     fault_diameter_in  load_hp     rpm position  file_number  de_len  fe_len  \
# 0               0.007        0  1797.0     None        122.0  244739  244739
# 1               0.007        1  1772.0     None        123.0  487384  487384
# 2               0.007        2  1750.0     None        124.0  486804  486804
# 3               0.007        3  1730.0     None        125.0  488545  488545
# 4               0.014        0  1797.0     None        189.0  249146  249146
# 5               0.014        1  1772.0     None        190.0  486224  486224
# 6               0.014        2  1750.0     None        191.0  487384  487384
# 7               0.014        3  1730.0     None        192.0  486804  486804
# 8               0.021        0  1797.0     None        226.0  243938  243938
# 9               0.021        1  1772.0     None        227.0  486804  486804
# 10              0.021        2  1750.0     None        228.0  487384  487384
# 11              0.021        3  1730.0     None        229.0  486804  486804
# 12              0.007        0  1797.0     None        109.0  243938  243938
# 13              0.007        1  1772.0     None        110.0  486224  486224
# 14              0.007        2  1750.0     None        111.0  485643  485643
# 15              0.007        3  1730.0     None        112.0  485643  485643
# 16              0.014        0  1797.0     None        174.0   63788   63788
# 17              0.014        1  1772.0     None        175.0  381890  381890
# 18              0.014        2  1750.0     None        176.0  487964  487964
# 19              0.014        3  1730.0     None        177.0  485063  485063
# 20              0.021        0  1797.0     None        213.0  244339  244339
# 21              0.021        1  1772.0     None        214.0  485063  485063
# 22              0.021        2  1750.0     None        215.0  491446  491446
# 23              0.021        3  1730.0     None        217.0  489125  489125
# 24              0.007        0  1797.0    12:00        161.0  129969  129969
# 25              0.007        0  1797.0     3:00        148.0  124602  124602
# 26              0.007        0  1797.0     6:00        135.0  243538  243538
# 27              0.007        1  1772.0    12:00        162.0  482742  482742
# 28              0.007        1  1772.0     3:00        149.0  485063  485063
# 29              0.007        1  1772.0     6:00        136.0  486804  486804
# 30              0.007        2  1750.0    12:00        163.0  483323  483323
# 31              0.007        2  1750.0     3:00        150.0  485643  485643
# 32              0.007        2  1750.0     6:00        137.0  486804  486804
# 33              0.007        3  1730.0    12:00        164.0  484483  484483
# 34              0.007        3  1730.0     3:00        151.0  486224  486224
# 35              0.007        3  1730.0     6:00        138.0  487964  487964
# 36              0.014        0  1797.0     6:00        201.0  245140  245140
# 37              0.014        1  1772.0     6:00        202.0  484483  484483
# 38              0.014        2  1750.0     6:00        203.0  486804  486804
# 39              0.014        3  1730.0     6:00        204.0  488545  488545
# 40              0.021        0  1797.0    12:00        262.0  130549  130549
# 41              0.021        0  1797.0     3:00        250.0  128663  128663
# 42              0.021        0  1797.0     6:00        238.0  246342  246342
# 43              0.021        1  1772.0    12:00        263.0  486224  486224
# 44              0.021        1  1772.0     3:00        251.0  489705  489705
# 45              0.021        1  1772.0     6:00        239.0  489125  489125
# 46              0.021        2  1750.0    12:00        264.0  486804  486804
# 47              0.021        2  1750.0     3:00        252.0  487384  487384
# 48              0.021        2  1750.0     6:00        240.0  487964  487964
# 49              0.021        3  1730.0    12:00        265.0  486224  486224
# 50              0.021        3  1730.0     3:00        253.0  484483  484483
# 51              0.021        3  1730.0     6:00        241.0  489125  489125
# 52                NaN        0     NaN      NaN          NaN  243938  243938
# 53                NaN        1     NaN      NaN          NaN  483903  483903
# 54                NaN        2     NaN      NaN          NaN  485063  485063
# 55                NaN        3     NaN      NaN          NaN  485643  485643
#
#    ba_len  rpm_reported  duration_s
# 0    None        1796.0        5.10
# 1    None        1772.0       10.15
# 2    None        1747.0       10.14
# 3    None        1721.0       10.18
# 4    None        1797.0        5.19
# 5    None        1772.0       10.13
# 6    None        1748.0       10.15
# 7    None        1725.0       10.14
# 8    None        1797.0        5.08
# 9    None        1774.0       10.14
# 10   None        1754.0       10.15
# 11   None        1729.0       10.14
# 12   None        1796.0        5.08
# 13   None        1772.0       10.13
# 14   None        1748.0       10.12
# 15   None        1721.0       10.12
# 16   None        1796.0        1.33
# 17   None        1772.0        7.96
# 18   None        1751.0       10.17
# 19   None        1726.0       10.11
# 20   None        1796.0        5.09
# 21   None        1774.0       10.11
# 22   None        1752.0       10.24
# 23   None        1727.0       10.19
# 24   None        1796.0        2.71
# 25   None        1797.0        2.60
# 26   None        1796.0        5.07
# 27   None        1772.0       10.06
# 28   None        1773.0       10.11
# 29   None        1774.0       10.14
# 30   None        1749.0       10.07
# 31   None        1750.0       10.12
# 32   None        1750.0       10.14
# 33   None        1723.0       10.09
# 34   None        1724.0       10.13
# 35   None        1725.0       10.17
# 36   None        1796.0        5.11
# 37   None        1772.0       10.09
# 38   None        1749.0       10.14
# 39   None        1723.0       10.18
# 40   None        1796.0        2.72
# 41   None        1796.0        2.68
# 42   None        1796.0        5.13
# 43   None        1771.0       10.13
# 44   None        1770.0       10.20
# 45   None        1771.0       10.19
# 46   None        1746.0       10.14
# 47   None        1746.0       10.15
# 48   None        1747.0       10.17
# 49   None        1718.0       10.13
# 50   None        1719.0       10.09
# 51   None        1719.0       10.19
# 52   None        1796.0        5.08
# 53   None           NaN       10.08
# 54   None           NaN       10.11
# 55   None        1725.0       10.12

# %%
manifest.groupby("category")[["de_len", "duration_s", "rpm_reported"]].describe().T
# Out:
# category                    fault         normal
# de_len       count      52.000000       4.000000
#              mean   411861.711538  424636.750000
#              std    131280.002868  120468.005253
#              min     63788.000000  243938.000000
#              25%    348704.000000  423911.750000
#              50%    486224.000000  484483.000000
#              75%    487384.000000  485208.000000
#              max    491446.000000  485643.000000
# duration_s   count      52.000000       4.000000
#              mean        8.580577       8.847500
#              std         2.734850       2.511724
#              min         1.330000       5.080000
#              25%         7.267500       8.830000
#              50%        10.130000      10.095000
#              75%        10.150000      10.112500
#              max        10.240000      10.120000
# rpm_reported count      52.000000       2.000000
#              mean     1760.134615    1760.500000
#              std        27.485489      50.204581
#              min      1718.000000    1725.000000
#              25%      1741.750000    1742.750000
#              50%      1762.000000    1760.500000
#              75%      1779.500000    1778.250000
#              max      1797.000000    1796.000000

# %% [markdown]
# ### Same fault condition across loads — does load affect the signal, independent of fault type?
#
# Fix one fault type × severity at random (and, for outer-race faults, one clock position), then plot that exact same physical condition's raw `DE_time` signal at all 4 loads (0–3 hp) — isolating the effect of motor load from fault type, complementing the fixed-load, varying-fault-type comparison below.

# %%
import random

random.seed(42)

# All unique fault_location x fault_diameter combinations (the 9 fault classes) — reused below too.
fault_types = sorted({
    (row["fault_location"], row["fault_diameter_in"])
    for _, row in manifest[manifest["category"] == "fault"].iterrows()
})

# Fix one fault type + severity (and, for outer-race, one clock position) so every subplot below
# is the *same* physical fault, varying only load.
fixed_location, fixed_diameter = random.choice(fault_types)
position_candidates = manifest.loc[
    (manifest["fault_location"] == fixed_location) & (manifest["fault_diameter_in"] == fixed_diameter),
    "position",
].dropna().unique().tolist()
fixed_position = random.choice(position_candidates) if position_candidates else None

sample_paths = {}
for load in sorted(manifest["load_hp"].unique()):
    mask = (
        (manifest["fault_location"] == fixed_location)
        & (manifest["fault_diameter_in"] == fixed_diameter)
        & (manifest["load_hp"] == load)
    )
    if fixed_position is not None:
        mask &= manifest["position"] == fixed_position
    sample_paths[load] = manifest.loc[mask, "path"].iloc[0]

n_samples = 2048  # zoom in on a short window, same as the normal-vs-fault plot below
t = np.arange(n_samples) / SAMPLE_RATE_HZ * 1000  # ms

fig, axes = plt.subplots(len(sample_paths), 1, figsize=(10, 9), sharex=True, sharey=True)
for ax, (load, path) in zip(axes, sample_paths.items()):
    de, *_ = load_signals(path)
    ax.plot(t, de[:n_samples])
    ax.set_title(f"{load} hp — {os.path.basename(path)}")
    ax.set_ylabel("Acceleration (g)")
axes[-1].set_xlabel("Time (ms)")
condition_label = f"{fixed_location}_{fixed_diameter:.3f}" + (f" ({fixed_position})" if fixed_position else "")
fig.suptitle(f"Same fault condition ({condition_label}) across all 4 loads", y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### One sample per fault×severity class, plus normal
#
# The 10 classification targets used throughout this project: `normal`, plus 3 fault locations (`inner_race`, `ball`, `outer_race`) × 3 severities (0.007"/0.014"/0.021" diameter). Fixing `load_hp=0` isolates the effect of fault type/severity from the load comparison above — one random file per class (for `outer_race`, which has 3 clock positions per severity, one position is picked at random).

# %%
load_for_comparison = 0  # fixed load, so amplitude/shape differences reflect fault type, not motor load

# fault_types was already computed in the cell above (reused here, not recomputed).
class_paths = {
    "normal": random.choice(
        manifest.loc[
            (manifest["category"] == "normal") & (manifest["load_hp"] == load_for_comparison), "path"
        ].tolist()
    )
}
for location, diameter in fault_types:
    label = f"{location}_{diameter:.3f}"
    candidates = manifest.loc[
        (manifest["fault_location"] == location)
        & (manifest["fault_diameter_in"] == diameter)
        & (manifest["load_hp"] == load_for_comparison),
        "path",
    ].tolist()
    class_paths[label] = random.choice(candidates)

fig, axes = plt.subplots(5, 2, figsize=(14, 16), sharex=True, sharey=True)
for ax, (label, path) in zip(axes.flat, class_paths.items()):
    de, *_ = load_signals(path)
    ax.plot(t, de[:n_samples])
    ax.set_title(f"{label} — {os.path.basename(path)}", fontsize=9)
    ax.set_ylabel("Acceleration (g)")
for ax in axes[-1]:
    ax.set_xlabel("Time (ms)")
fig.suptitle(f"One file per class, all at {load_for_comparison} hp", y=1.005)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Time-domain: normal vs. fault drive-end signal

# %%
normal_de, *_ = load_signals(os.path.join(NORMAL_DIR, "normal_0hp.mat"))
fault_path = os.path.join(DRIVE_END_48K_DIR, "48k_drive_end_fault_inner_race_0.007in_0hp_1797rpm_109.mat")
fault_de, *_ = load_signals(fault_path)

n_samples = 2048  # zoom in on a short window rather than plotting the full multi-second signal
t = np.arange(n_samples) / SAMPLE_RATE_HZ * 1000  # ms

fig, axes = plt.subplots(2, 1, figsize=(10, 6), sharex=True, sharey=True)
axes[0].plot(t, normal_de[:n_samples])
axes[0].set_title("Normal (0 hp)")
axes[1].plot(t, fault_de[:n_samples], color="tab:red")
axes[1].set_title("Inner race fault, 0.007in, 0hp (file 109)")
axes[1].set_xlabel("Time (ms)")
for ax in axes:
    ax.set_ylabel("Acceleration (g)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Frequency-domain: FFT comparison
#
# A bearing fault typically shows up as extra energy at characteristic defect frequencies that a healthy bearing's spectrum lacks.

# %%
def spectrum(signal, sample_rate=SAMPLE_RATE_HZ):
    n = len(signal)
    freqs = np.fft.rfftfreq(n, d=1 / sample_rate)
    mags = np.abs(np.fft.rfft(signal)) / n  # normalize by length so magnitude doesn't scale with signal duration
    return freqs, mags

freq_n, mag_n = spectrum(normal_de)
freq_f, mag_f = spectrum(fault_de)

fig, ax = plt.subplots(figsize=(10, 4))
max_freq = 3000  # bearing defect frequencies of interest sit well under this for these RPMs
ax.plot(freq_n[freq_n < max_freq], mag_n[freq_n < max_freq], label="Normal", alpha=0.8)
ax.plot(freq_f[freq_f < max_freq], mag_f[freq_f < max_freq], label="Inner race fault, 0.007in", alpha=0.8)
ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Magnitude")
ax.set_title("FFT of drive-end signal (0-3 kHz)")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature representations, side by side
#
# For the same fault window above (inner race, 0.007in, 0hp, file 109), compare all five representations this project computes from it: raw time domain, FFT magnitude spectrum, Hilbert-envelope spectrum, the 9 RMS-normalized fault-frequency peaks (`data_splitting_preprocessing.ipynb`/`src/feature_extraction.py`), and the CWT scalogram (`cwt_baseline_exploration.ipynb`) — the one representation that's a 2D image rather than a flat feature vector. Uses `src/` directly rather than redefining the extraction logic inline, since it's the same reusable code the later notebooks and the agent call.

# %%
from src.feature_extraction import (
    FAULT_FREQ_FEATURE_NAMES,
    extract_cwt,
    extract_envelope,
    extract_fault_freq,
    extract_fft,
    extract_time,
    resolve_rpm,
)

WINDOW_SIZE = 4096
example_window = fault_de[:WINDOW_SIZE]
example_rpm = resolve_rpm(load_hp=0)  # nominal RPM for 0 hp

time_feat = extract_time(example_window)
fft_feat = extract_fft(example_window)
envelope_feat = extract_envelope(example_window)
fault_freq_feat = extract_fault_freq(example_window, rpm=example_rpm)
cwt_feat = extract_cwt(example_window)

fft_freqs = np.fft.rfftfreq(WINDOW_SIZE, d=1 / SAMPLE_RATE_HZ)
max_freq = 3000

fig = plt.figure(figsize=(14, 11))
gs = fig.add_gridspec(3, 2)

ax_time = fig.add_subplot(gs[0, 0])
ax_time.plot(np.arange(WINDOW_SIZE) / SAMPLE_RATE_HZ * 1000, time_feat)
ax_time.set_title("Raw time domain")
ax_time.set_xlabel("Time (ms)")
ax_time.set_ylabel("Acceleration (g)")

ax_fft = fig.add_subplot(gs[0, 1])
ax_fft.plot(fft_freqs[fft_freqs < max_freq], fft_feat[fft_freqs < max_freq])
ax_fft.set_title("FFT magnitude spectrum")
ax_fft.set_xlabel("Frequency (Hz)")
ax_fft.set_ylabel("Magnitude")

ax_env = fig.add_subplot(gs[1, 0])
ax_env.plot(fft_freqs[fft_freqs < max_freq], envelope_feat[fft_freqs < max_freq], color="tab:orange")
ax_env.set_title("Envelope spectrum")
ax_env.set_xlabel("Frequency (Hz)")
ax_env.set_ylabel("Magnitude")

ax_ff = fig.add_subplot(gs[1, 1])
ax_ff.bar(FAULT_FREQ_FEATURE_NAMES, fault_freq_feat, color="tab:green")
ax_ff.set_title("Fault-frequency peaks (RMS-normalized)")
ax_ff.tick_params(axis="x", rotation=45)
ax_ff.set_ylabel("Normalized magnitude")

ax_cwt = fig.add_subplot(gs[2, :])
im = ax_cwt.imshow(cwt_feat, aspect="auto", origin="lower", cmap="viridis")
ax_cwt.set_title("CWT scalogram")
ax_cwt.set_xlabel("Time (downsampled)")
ax_cwt.set_ylabel("Scale (high freq → low freq)")
fig.colorbar(im, ax=ax_cwt, label="|CWT coefficient|")

fig.suptitle(f"Five feature representations of the same window — {os.path.basename(fault_path)}", y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Combine chosen directories into one .mat dataset
#
# Load every file from a chosen set of directories — here `data/48k_drive_end_fault` and `data/normal_baseline_data` — and write them all into a single `combined_dataset.mat`, one MATLAB struct per source file (signals kept at their original, unsliced length) carrying both the signals and the fault metadata.

# %%
import scipy.io as sio

# Directories to combine — edit this list to control what goes into combined_dataset.mat
SOURCE_DIRS = [DRIVE_END_48K_DIR, NORMAL_DIR]

combine_paths = sorted(
    os.path.join(sub_dir, f)
    for sub_dir in SOURCE_DIRS
    for f in os.listdir(sub_dir)
)

combined = {}
for path in combine_paths:
    info = label_file(path)
    de, fe, ba, rpm_reported = load_signals(path)

    # savemat needs valid MATLAB identifiers as top-level variable names, so key by
    # category + id instead of the raw filename (which contains "." and other symbols).
    if info["category"] == "normal":
        var_name = f"normal_{info['load_hp']}hp"
    else:
        var_name = f"fault_{info['file_number']}"

    combined[var_name] = {
        "filename": os.path.basename(path),
        "DE_time": de if de is not None else np.array([]),
        "FE_time": fe if fe is not None else np.array([]),
        "BA_time": ba if ba is not None else np.array([]),
        "rpm_reported": rpm_reported if rpm_reported is not None else np.nan,
        # savemat can't serialize Python None, so blank out any missing fields (e.g. position on non-outer-race faults)
        **{k: (v if v is not None else "") for k, v in info.items()},
    }

output_path = os.path.join(DATA_DIR, "combined_dataset.mat")
sio.savemat(output_path, combined)
print(f"Saved {len(combined)} file-structs from {len(SOURCE_DIRS)} directories to {output_path}")
# Out:
# Saved 56 file-structs from 2 directories to data/combined_dataset.mat
